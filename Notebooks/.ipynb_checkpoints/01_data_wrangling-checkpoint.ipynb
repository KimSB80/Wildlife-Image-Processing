# %% [markdown]
# ## Data Wrangling and EDA for Wildlife Image Classification

# %% [markdown]
# The data for this project is sources from https://www.kaggle.com/datasets/akash2907/bird-species-classification

# %% [markdown]
# ### Load Data and Import Packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import imageio.v2 as imageio
import cv2

# %% [markdown]
# #### Visualizing one image

# %%
# load two images
im1 = imageio.imread('../jpeg/train/blasti/DSC_6382.jpg')
im2 = imageio.imread('../jpeg/train/blasti/DSC_6389.jpg')

# Print image attributes
print('Image type:', type(im1))
print('Shape of image1 array:', im1.shape)
print('Shape of image2 array:', im2.shape)
# Out:
# Image type: <class 'imageio.core.util.Array'>
# Shape of image1 array: (4000, 6016, 3)
# Shape of image2 array: (2671, 6016, 3)

# %%
# Print available metadata fields
print(im1.meta.keys())
# Out:
# odict_keys(['exif', 'dpi', 'photoshop', 'adobe', 'adobe_transform', 'icc_profile', 'EXIF_MAIN'])

# %%
#im1.meta.EXIF_MAIN

# %% [markdown]
# There is some metadata associated with the photo settings for each image, but I will not use this type of data for the purposes of this project.

# %%
# view images
fig, ax = plt.subplots(nrows=1, ncols=2, tight_layout=True, figsize=(15,15))

ax[0].imshow(im1, cmap='gray')
ax[1].imshow(im2, cmap='gray')
#plt.axis('off');

# %% [markdown]
# #### Loading all images

# %%
## Function for loading images from multiple folders

def load_images_from_folder(folder):
    images = []

    for filename in os.listdir(folder):
        if filename.endswith(".jpg"):
            img = imageio.imread(os.path.join(folder, filename))
            if img is not None:
                images.append(img)
    return images

# %%
## Get list of folder names
train_path = "../jpeg/train"
test_path = "../jpeg/test"

folder_names = os.listdir(train_path)[1:2]

# %%
# Load training images
#root_folder = '../jpeg/train'
folders = [os.path.join(train_path, x) for x in folder_names]
train_images = [img for folder in folders for img in load_images_from_folder(folder)]

train_images = np.array(train_images)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_t/j72rr4rs6q5g2v8lv7qyn_rsb_4wb3/T/ipykernel_18738/2132045711.py in <module>
#       3 folders = [os.path.join(train_path, x) for x in folder_names]
#       4 train_images = [img for folder in folders for img in load_images_from_folder(folder)]
# ----> 5 train_images = np.array(train_images)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.

# %%
## Trying to understand the data -- is the first image stored as first item in list?
## why is the third value 31 and not 3?
train_images.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_t/j72rr4rs6q5g2v8lv7qyn_rsb_4wb3/T/ipykernel_18738/404838268.py in <module>
#       1 ## Trying to understand the data -- is the first image stored as first item in list?
#       2 ## why is the third value 31 and not 3?
# ----> 3 train_images.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
# Plot sample image
plt.imshow(train_images[1], cmap='gray')
plt.axis('off');

# %%
# set path and folder names
train_path = "../jpeg/train"
#folder_names = os.listdir(train_path)[1:]

folder_names = os.listdir(train_path)[1:3] # load just two folders for now
folder_names
# Out:
# ['cbrtsh', 'hsparo']

# %% [markdown]
# ### Trying out another way to load images that also loads labels.
# The code below is supposed to loop through each folder and load all images, simultanseously storing the folder name (i.e. bird species) as the label.

# %%
# LOAD A SUBSET OF DATA FOR NOW...
folder_names = os.listdir(train_path)[1:3] # load just two folders for now

data=[]
labels = []

for folder in folder_names:
    img_path = os.path.join(train_path, folder) 
    
    for filename in os.listdir(img_path):
        if filename.endswith(".jpg"):
            img = imageio.imread(os.path.join(img_path, filename))
        
            #im = im.resize((30,30))       
            #im = np.array(img)
            data.append(im)
            labels.append(folder)

    
x_train = np.array(data)
x_train_labels = np.array(labels)
print("success")
# Out:
# success

# %%
type(x_train)
x_train.shape
# Out:
# (6, 2684, 6016, 3)

# %%
x_train_labels.shape
# Out:
# (6,)

# %% [markdown]
# The x_train_labels shape does not appear to be correct. There should be two different labels and ~15 images.

# %%
# Plot sample image
plt.imshow(x_train[4], cmap='gray')
plt.axis('off');

# %% [markdown]
# When I plot the images from x_train above, it looks like just one image loaded!

# %%
## Use ImageDataGenerator to resizedata and covert to rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/kaggle/input/bird-species-classification/train_data/train_data'
test_dir = '/kaggle/input/bird-species-classification/test_data/test_data'

# Use this to resize and convert to gray
train_gen = ImageDataGenerator(
    rescale = 1. /255,
    zoom_range = 0.2,
    horizontal_flip = True,
    validation_split= 0.2
)

# %%
## Extra code for creating subplots later...

# %%
# plot all images for each species
# trying to understand this code to adapt it...

fig, axs = plt.subplots(nrows=146, ncols=4, tight_layout=True, figsize=(15,365))
#fig.suptitle('', fontsize=14)

for ax, image in zip(axs.ravel(), mal_ims):
    path = '../input/siim-isic-melanoma-classification/jpeg/train/' + str(image) + '.jpg'
    im = imageio.imread(path)
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(image)
